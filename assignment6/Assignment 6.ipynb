# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('weather.csv');
rk=pd.DataFrame(df)
print(df.shape)
rk.head()
# Out:
# (366, 24)
#         Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  11/1/2007  Canberra      8.0     24.3       0.0          3.4       6.3
# 1  11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 2  11/3/2007  Canberra     13.7     23.4       3.6          5.8       3.3
# 3  11/4/2007  Canberra     13.3     15.5      39.8          7.2       9.1
# 4  11/5/2007  Canberra      7.6     16.1       2.8          5.6      10.6
#
#   WindGustDir  WindGustSpeed WindDir9am      ...      Humidity3pm  \
# 0          NW           30.0         SW      ...               29
# 1         ENE           39.0          E      ...               36
# 2          NW           85.0          N      ...               69
# 3          NW           54.0        WNW      ...               56
# 4         SSE           50.0        SSE      ...               49
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
x=df['MinTemp']
sns.distplot(x)
# Out:
# C:\Users\RISHABH\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.distplot(x,kde=False,rug=True)
# Out:
# C:\Users\RISHABH\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
y=df['MaxTemp']
sns.distplot(y,hist=False,rug=True)

# %%
x=df['MaxTemp']
sns.distplot(x)
# Out:
# C:\Users\RISHABH\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.kdeplot(x, shade=True)

# %%
a=df['Evaporation']
sns.kdeplot(a, label='original')
sns.kdeplot(a, bw=0.5, label='bw=0.5')
sns.kdeplot(a, bw=1.5, label='bw=2')
#plt.legend()

# %%
a = pd.DataFrame(df, columns=['Humidity3pm', 'Humidity9am'])
a.head()
# Out:
#    Humidity3pm  Humidity9am
# 0           29           68
# 1           36           80
# 2           69           82
# 3           56           62
# 4           49           68

# %%
a.plot(kind='scatter', x = 'Humidity3pm', y = 'Humidity9am')

# %%
sns.jointplot(x='Humidity3pm', y='Humidity9am', data=a)
# Out:
# C:\Users\RISHABH\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\RISHABH\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
with sns.axes_style('white'):
    sns.jointplot(x = df['MinTemp'], y =df['MaxTemp'], kind = 'hex', color = 'r', data=a )
# Out:
# C:\Users\RISHABH\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# C:\Users\RISHABH\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot(x=df['MinTemp'], y=df['MaxTemp'],  kind='kde')

# %%
rk = pd.DataFrame(df, columns=['Pressure3pm', 'Pressure9am','MinTemp','MaxTemp'])
sns.pairplot(rk)

# %%
sns.pairplot(rk, hue='MaxTemp')

# %%
r=pd.DataFrame(df)

r.describe(include='all')
# Out:
#              Date  Location     MinTemp     MaxTemp    Rainfall  Evaporation  \
# count         366       366  366.000000  366.000000  366.000000   366.000000
# unique        366         1         NaN         NaN         NaN          NaN
# top     4/19/2008  Canberra         NaN         NaN         NaN          NaN
# freq            1       366         NaN         NaN         NaN          NaN
# mean          NaN       NaN    7.265574   20.550273    1.428415     4.521858
# std           NaN       NaN    6.025800    6.690516    4.225800     2.669383
# min           NaN       NaN   -5.300000    7.600000    0.000000     0.200000
# 25%           NaN       NaN    2.300000   15.025000    0.000000     2.200000
# 50%           NaN       NaN    7.450000   19.650000    0.000000     4.200000
# 75%           NaN       NaN   12.500000   25.500000    0.200000     6.400000
# max           NaN       NaN   20.900000   35.800000   39.800000    13.800000
#
# ...

# %%
sns.stripplot(x ='Rainfall', y='Sunshine', data=r,jitter=False)

# %%
sns.stripplot(x='Rainfall', y='Sunshine', data=r, jitter=True)

# %%
sns.swarmplot(x='Humidity3pm', y='Pressure3pm', data=r)

# %%
sns.boxplot(x='Cloud9am', y='Humidity9am', data=r)

# %%
print(r[r.WindDir9am=='E'])
# Out:
#            Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 1     11/2/2007  Canberra     14.0     26.9       3.6          4.4       9.7
# 8     11/9/2007  Canberra      8.8     19.5       0.0          4.0       4.1
# 11   11/12/2007  Canberra      8.5     27.3       0.2          7.2      12.5
# 25   11/26/2007  Canberra     15.6     26.9       0.0          6.8       8.9
# 26   11/27/2007  Canberra     13.3     22.2       0.2          6.6       2.3
# 30    12/1/2007  Canberra     15.1     20.4      22.6          2.4       0.2
# 31    12/2/2007  Canberra     11.6     26.3       4.2          1.6      12.0
# 37    12/8/2007  Canberra     16.5     28.2       4.0          4.2       8.8
# 67     1/7/2008  Canberra     16.5     33.9       0.0          9.0      12.6
# 68     1/8/2008  Canberra     16.5     30.3       0.0         10.0       8.1
# 69     1/9/2008  Canberra     17.5     29.9       0.0          6.6       8.8
# ...

# %%
r.Rainfall[r.WindDir9am=='E'].value_counts()
# Out:
# 0.0     13
# 0.2      3
# 4.2      1
# 22.6     1
# 3.6      1
# 0.6      1
# 6.2      1
# 4.0      1
# Name: Rainfall, dtype: int64

# %%
sns.boxplot(x='RainToday', y='Humidity9am', data=r, hue='WindDir3pm', dodge=True)

# %%
sns.boxplot(x='RainToday', y='Humidity9am', data=r, hue='WindDir3pm', dodge=False)

# %%
sns.barplot(x='RainToday', y='Rainfall', data=r)

# %%
sns.boxplot(x='RainToday', y='Humidity3pm', data=r, hue='WindDir9am', dodge=True)

# %%
sns.barplot(x='RainTomorrow', y='Rainfall', data=r)

# %%
sns.barplot(x='RainToday', y='Rainfall', hue='WindDir9am', data=r)

# %%
sns.countplot(x='WindDir9am', data=r, palette='Blues_d')

# %%
sns.countplot(x='WindDir3pm', data=r, palette='Blues_d')
